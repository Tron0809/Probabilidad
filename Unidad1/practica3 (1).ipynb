# %% [markdown]
# #Probabilidad y estadistica
# ## Falicitador: Jose Gabriel Rodriguez Jose Rivaz
# #Alumno: Jasiel Aleksei Terrones González
# ![image.png](data:image/png;base64,...)

# %%
from statistics import*

# %%
#Estadistica de los corredores
tiempos=[17.20, 15.10,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]
print(tiempos)
# Out:
# [17.2, 15.1, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
print("El tiempo promedio de los corredores es=>", mean(tiempos))
# Out:
# El tiempo promedio de los corredores es=> 17.322

# %%
mediana = median(tiempos100mts)
print("La media de los tiempos de los corredores es=>",mediana)
# Out:
# La media de los tiempos de los corredores es=> 17.15

# %%
moda= mode(tiempos)
print("La moda de los tiempos es=>",moda)
# Out:
# La moda de los tiempos es=> 15.1

# %%
multimodas = multimode (tiempos)
print("La moda de los tiempos es =>",[multimodas])
# Out:
# La moda de los tiempos es => [[15.1]]
