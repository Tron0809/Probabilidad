# %% [markdown]
# #Ejemplo 3: Histogramas de 2 grupos
# 1. En ete ejemplo generaremos 100 numeros aleatorios reales que representan la produccion diara de 100 telares (Medidas en metros)
# 2. Generar otra lista con la produccion de 100 telares para una segunda fabrica
# 3. Con estas listas de valores se pretende determinar las medidas de tendencia central, es decir, la media, la moda, la mediana y la desviacion estandar
# 4. Graficar un histograma para cada fabrica

# %%
from statistics import*

# %%
#Libreria para generar numeros aleatorios
import random

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(50, 100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [58.0, 94.57, 88.26, 78.4, 95.13, 81.88, 83.99, 96.37, 70.57, 64.29, 73.6, 72.72, 99.69, 81.7, 80.91, 93.0, 54.91, 61.46, 68.63, 58.0, 77.0, 74.55, 92.1, 77.44, 58.85, 87.78, 94.91, 73.66, 51.51, 96.05, 81.44, 82.19, 68.58, 98.16, 96.12, 93.25, 90.1, 78.28, 67.52, 95.77, 56.42, 71.06, 98.03, 97.37, 79.75, 67.92, 70.26, 71.99, 89.35, 97.45, 66.54, 64.31, 56.62, 61.51, 76.36, 65.26, 83.75, 98.82, 77.09, 74.75, 69.31, 58.7, 50.89, 71.46, 83.5, 79.03, 83.41, 98.56, 66.15, 59.62, 55.02, 63.78, 90.08, 75.54, 62.44, 87.33, 52.59, 96.32, 59.65, 54.05, 56.23, 93.9, 93.8, 88.69, 51.73, 72.5, 76.48, 89.24, 96.31, 68.81, 85.72, 59.74, 56.82, 81.91, 66.61, 97.61, 62.24, 82.76, 70.99, 64.06]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round( random.uniform(50, 100),2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [72.37, 75.91, 93.38, 52.01, 77.85, 65.05, 59.94, 68.72, 86.66, 53.08, 70.6, 79.27, 54.54, 89.35, 83.76, 75.58, 69.83, 93.28, 78.42, 92.49, 76.48, 55.69, 83.24, 89.57, 80.47, 64.92, 62.2, 65.92, 78.39, 55.79, 62.36, 70.24, 95.45, 73.08, 71.48, 60.99, 88.61, 69.63, 88.44, 50.62, 84.17, 65.88, 64.49, 59.53, 53.39, 74.89, 63.24, 79.98, 51.62, 79.91, 91.64, 79.73, 53.5, 90.57, 93.39, 96.31, 92.82, 73.27, 81.12, 76.57, 67.61, 90.35, 68.26, 81.0, 96.5, 94.21, 65.44, 91.08, 79.87, 55.6, 67.14, 76.93, 71.49, 58.22, 60.2, 76.94, 74.09, 82.34, 52.98, 83.07, 59.33, 71.63, 99.53, 73.9, 81.16, 85.58, 66.88, 56.91, 56.03, 68.3, 65.74, 99.0, 99.37, 60.43, 76.14, 73.19, 61.55, 62.88, 64.3, 51.51]

# %%
#Libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
media =mean(fabrica1)
mediana = median(fabrica1)
moda= mode(fabrica1)

print("Valores del a fabrica 1")
print("La media es =",media)
print("La mediana  es",mediana)
print("la moda es ",moda)
# Out:
# Valores del a fabrica 1
# La media es = 76.4953
# La mediana  es 76.42
# la moda es  58.0

# %%
media =mean(fabrica2)
mediana = median(fabrica2)
moda= mode(fabrica2)

print("Valores del a fabrica 2")
print("La media es =",media)
print("La mediana  es",mediana)
print("la moda es ",moda)
# Out:
# Valores del a fabrica 2
# La media es = 73.6836
# La mediana  es 73.22999999999999
# la moda es  72.37

# %%
#Generar 2 subplot de 1 un reglon por 2 columnas para desplegar los 2 histogtramas,
#Una al lado de la otra
fig, (ax1, ax2)=plt.subplots(nrows=1, ncols=2)

# %%
#Generar 2 subplot de 1 un reglon por 2 columnas para desplegar los 2 histogtramas,
#Una al lado de la otra
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
#Valor minimo,maximo, rango
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

# %%
plt.hist(fabrica1,bins=20, alpha=0.2, color="b", edgecolor= "black")
plt.axvline(media1, color="b", linestyle="dashed", linewidth=2, label="Media")
plt.axvline(mediana1, color="r", linestyle="dashed", linewidth=2, label="Mediana")
plt.axvline(moda1, color="y", linestyle="dashed", linewidth=2, label="Moda")
plt.xlabel=("Valor")
plt.ylabel("Frecuencia")
plt.title("Producción diara de la fabrica 1")
plt.legend()
plt.show()

# %%
#Valor minimo,maximo, rango
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

plt.hist(fabrica2,bins=10, alpha=0.2, color="b", edgecolor= "black")
plt.axvline(media2, color="b", linestyle="dashed", linewidth=2, label="Media")
plt.axvline(mediana2, color="r", linestyle="dashed", linewidth=2, label="Mediana")
plt.axvline(moda2, color="y", linestyle="dashed", linewidth=2, label="Moda")
plt.xlabel=("Valor")
plt.ylabel("Frecuencia")
plt.title("Producción diara de la fabrica 2")
plt.legend()
plt.show()
