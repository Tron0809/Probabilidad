# %% [markdown]
# #Ejemplo 3: Histogramas de 2 grupos
# 1. En ete ejemplo generaremos 100 numeros aleatorios reales que representan la produccion diara de 100 telares (Medidas en metros)
# 2. Generar otra lista con la produccion de 100 telares para una segunda fabrica
# 3. Con estas listas de valores se pretende determinar las medidas de tendencia central, es decir, la media, la moda, la mediana y la desviacion estandar
# 4. Graficar un histograma para cada fabrica

# %%
from statistics import*

# %%
#Libreria para generar numeros aleatorios
import random

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(50, 100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [73.51, 53.84, 59.77, 94.95, 83.31, 98.31, 62.79, 89.21, 63.46, 75.6, 92.07, 60.66, 96.8, 72.45, 76.83, 64.96, 95.23, 63.96, 75.1, 84.78, 64.25, 87.38, 91.94, 73.79, 66.83, 50.95, 81.61, 82.04, 65.08, 99.44, 82.45, 75.2, 62.22, 51.02, 74.06, 65.2, 85.87, 79.8, 69.14, 63.12, 55.33, 67.54, 73.87, 73.38, 87.23, 62.6, 68.31, 58.08, 90.56, 52.93, 99.63, 57.03, 99.04, 80.59, 84.28, 64.91, 71.66, 59.74, 78.48, 60.99, 90.75, 58.05, 56.53, 88.06, 53.71, 67.63, 61.42, 70.06, 54.34, 67.07, 59.53, 95.04, 72.5, 74.38, 69.56, 78.08, 64.72, 85.52, 80.96, 88.66, 66.85, 90.14, 86.35, 87.31, 68.84, 57.93, 69.31, 52.3, 63.82, 60.75, 91.02, 85.29, 88.41, 82.74, 79.39, 72.98, 54.16, 72.52, 87.87, 87.59]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round( random.uniform(50, 100),2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [65.72, 54.22, 58.11, 78.01, 71.85, 80.32, 67.13, 74.8, 65.91, 55.08, 67.72, 87.67, 69.83, 99.1, 66.49, 74.43, 97.35, 97.9, 87.97, 56.07, 96.98, 74.41, 86.31, 79.02, 92.55, 84.42, 82.01, 53.56, 53.42, 72.61, 84.86, 65.71, 64.37, 50.85, 90.95, 68.53, 57.75, 75.6, 86.65, 65.15, 86.29, 95.9, 97.7, 84.84, 92.9, 60.01, 76.61, 79.06, 83.26, 82.34, 58.74, 52.97, 62.34, 62.59, 77.68, 57.47, 86.29, 90.42, 66.08, 54.8, 90.4, 80.59, 75.46, 93.89, 90.78, 84.74, 55.73, 68.86, 55.0, 79.65, 62.03, 79.51, 64.03, 50.9, 98.48, 71.97, 63.78, 92.57, 71.53, 77.84, 99.08, 67.09, 93.62, 87.78, 88.65, 64.83, 60.3, 56.67, 71.2, 60.84, 78.66, 85.17, 74.74, 70.42, 90.38, 60.23, 94.05, 74.01, 74.28, 78.9]

# %%
#Libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
media =mean(fabrica1)
mediana = median(fabrica1)
moda= mode(fabrica1)

print("Valores del a fabrica 1")
print("La media es =",media)
print("La mediana  es",mediana)
print("la moda es ",moda)
# Out:
# Valores del a fabrica 1
# La media es = 73.973
# La mediana  es 73.18
# la moda es  73.51

# %%
media =mean(fabrica2)
mediana = median(fabrica2)
moda= mode(fabrica2)

print("Valores del a fabrica 2")
print("La media es =",media)
print("La mediana  es",mediana)
print("la moda es ",moda)
# Out:
# Valores del a fabrica 2
# La media es = 75.0832
# La mediana  es 74.77
# la moda es  86.29

# %%
#Generar 2 subplot de 1 un reglon por 2 columnas para desplegar los 2 histogtramas,
#Una al lado de la otra
fig, (ax1, ax2)=plt.subplots(nrows=1, ncols=2)

# %%
#Generar 2 subplot de 1 un reglon por 2 columnas para desplegar los 2 histogtramas,
#Una al lado de la otra
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
#Valor minimo,maximo, rango
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

# %%
plt.hist(fabrica1,bins=20, alpha=0.2, color="b", edgecolor= "black")
plt.axvline(media1, color="b", linestyle="dashed", linewidth=2, label="Media")
plt.axvline(mediana1, color="r", linestyle="dashed", linewidth=2, label="Mediana")
plt.axvline(moda1, color="y", linestyle="dashed", linewidth=2, label="Moda")
plt.xlabel=("Valor")
plt.ylabel("Frecuencia")
plt.title("Producción diara de la fabrica 1")
plt.legend()
plt.show()

# %%
#Valor minimo,maximo, rango
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

plt.hist(fabrica2,bins=10, alpha=0.2, color="b", edgecolor= "black")
plt.axvline(media2, color="b", linestyle="dashed", linewidth=2, label="Media")
plt.axvline(mediana2, color="r", linestyle="dashed", linewidth=2, label="Mediana")
plt.axvline(moda2, color="y", linestyle="dashed", linewidth=2, label="Moda")
plt.xlabel=("Valor")
plt.ylabel("Frecuencia")
plt.title("Producción diara de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# # ***Maximo,minimo y Rango***

# %%
maximo= max(fabrica1)
minimo = min(fabrica1)
rango= maximo - minimo
media=mean (fabrica1)
mediana = median(fabrica1)
moda= mode (fabrica1)

print ("Estadistica descriptiva de la fabrica 1 \n","media =",media,"\n mediana=",mediana,"\n moda =", moda,"\n minimo=",minimo,"\n rango",rango)
# Out:
# Estadistica descriptiva de la fabrica 1
#  media = 73.973
#  mediana= 73.18
#  moda = 73.51
#  minimo= 50.95
#  rango 48.67999999999999

# %%
maximo2= max(fabrica2)
minimo2 = min(fabrica2)
rango2= maximo - minimo
media2=mean (fabrica2)
mediana2 = median(fabrica2)
moda2= mode (fabrica2)

print ("Estadistica descriptiva de la fabrica 2 \n","media =",media2,"\n mediana=",mediana2,"\n moda =", moda2,"\n minimo=",minimo2,"\n rango",rango2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  media = 75.0832
#  mediana= 74.77
#  moda = 86.29
#  minimo= 50.85
#  rango 48.67999999999999

# %% [markdown]
# ## Dispersión de Datos

# %%
desviacion_estandar_fabrica1= stdev(fabrica1)
print("La desviacion estandar de la fabrica 1 es =", desviacion_estandar_fabrica1)
# Out:
# La desviacion estandar de la fabrica 1 es = 13.302485261837884

# %%
desviacion_estandar_fabrica2= stdev(fabrica2)
print("La desviacion estandar de la fabrica 2 es =", desviacion_estandar_fabrica2)
# Out:
# La desviacion estandar de la fabrica 2 es = 13.67995642677212

# %%
plt.figure(figsize=(10,8))
plt.hist(fabrica1,bins=10, alpha=0.2, color="b", edgecolor= "black")
plt.axvline(media1, color="b", linestyle="dashed", linewidth=2, label=f"Media={media1:.2f}")
plt.axvline(mediana1, color="r", linestyle="dashed", linewidth=2, label=f"Mediana={mediana1:.2f}")
plt.axvline(moda1, color="y", linestyle="dashed", linewidth=2, label=f'Moda={moda1:.2f}')

plt.axvline(media1 - desviacion_estandar_fabrica1, color="black", linestyle="dashed",
            linewidth=2, label=f'Desv Estandar={desviacion_estandar_fabrica1:.2f}')

plt.axvline(media1 + desviacion_estandar_fabrica1, color="black", linestyle="dashed",
            linewidth=2)
plt.xlabel=("Valor")
plt.ylabel("Frecuencia")
plt.title("Producción diara de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.hist(fabrica2,bins=10, alpha=0.2, color="b", edgecolor= "black")
plt.axvline(media2, color="b", linestyle="dashed", linewidth=2, label=f"Media={media2:.2f}")
plt.axvline(mediana2, color="r", linestyle="dashed", linewidth=2, label=f"Mediana={mediana2:.2f}")
plt.axvline(moda2, color="y", linestyle="dashed", linewidth=2, label=f'Moda={moda2:.2f}')

plt.axvline(media2 - desviacion_estandar_fabrica2, color="black", linestyle="dashed",
            linewidth=2, label=f'Desv Estandar={desviacion_estandar_fabrica2:.2f}')

plt.axvline(media2 + desviacion_estandar_fabrica2, color="black", linestyle="dashed",
            linewidth=2)
plt.xlabel=("Valor")
plt.ylabel("Frecuencia")
plt.title("Producción diara de la fabrica 1")
plt.legend()
plt.show()
